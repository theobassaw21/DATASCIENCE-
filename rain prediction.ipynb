# %%
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns
plt.style.use('dark_background')

# %%
data = pd.read_csv('weatherAUS.csv')
data
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
data.isna().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
msno.bar(data)
# Out:
# <AxesSubplot:>

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.tail(10)
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 145450  2017-06-16    Uluru      5.2     24.3       0.0          NaN
# 145451  2017-06-17    Uluru      6.4     23.4       0.0          NaN
# 145452  2017-06-18    Uluru      8.0     20.7       0.0          NaN
# 145453  2017-06-19    Uluru      7.4     20.6       0.0          NaN
# 145454  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 145450       NaN           E           24.0         SE  ...        53.0
# ...

# %%
data.loc[data['RainTomorrow'].isna()]
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 14      2008-12-15   Albury      8.4     24.6       0.0          NaN
# 283     2009-09-10   Albury      2.6      NaN       0.0          NaN
# 435     2010-02-09   Albury     22.1     35.1       0.0          NaN
# 437     2010-02-11   Albury     21.5     35.0       0.0          NaN
# 443     2010-02-17   Albury     15.5     30.6       0.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 144955  2016-02-07    Uluru     22.5     37.7       0.0          NaN
# 145091  2016-06-22    Uluru     12.3     19.1       0.0          NaN
# 145092  2016-06-23    Uluru     14.2     18.7       NaN          NaN
# 145335  2017-02-21    Uluru     13.5      NaN       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
data=data.drop(['Date','Location','Sunshine','Cloud9am','Cloud3pm','Evaporation'],axis=1)
data
# Out:
#         MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed WindDir9am  \
# 0          13.4     22.9       0.6           W           44.0          W
# 1           7.4     25.1       0.0         WNW           44.0        NNW
# 2          12.9     25.7       0.0         WSW           46.0          W
# 3           9.2     28.0       0.0          NE           24.0         SE
# 4          17.5     32.3       1.0           W           41.0        ENE
# ...         ...      ...       ...         ...            ...        ...
# 145455      2.8     23.4       0.0           E           31.0         SE
# 145456      3.6     25.3       0.0         NNW           22.0         SE
# 145457      5.4     26.9       0.0           N           37.0         SE
# 145458      7.8     27.0       0.0          SE           28.0        SSE
# 145459     14.9      NaN       0.0         NaN            NaN        ESE
#
#        WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# ...

# %%
plt.scatter(x=data['Rainfall'],y=data['MaxTemp'])

# %%
data=data.dropna(axis=0)
data
# Out:
#         MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed WindDir9am  \
# 0          13.4     22.9       0.6           W           44.0          W
# 1           7.4     25.1       0.0         WNW           44.0        NNW
# 2          12.9     25.7       0.0         WSW           46.0          W
# 3           9.2     28.0       0.0          NE           24.0         SE
# 4          17.5     32.3       1.0           W           41.0        ENE
# ...         ...      ...       ...         ...            ...        ...
# 145454      3.5     21.8       0.0           E           31.0        ESE
# 145455      2.8     23.4       0.0           E           31.0         SE
# 145456      3.6     25.3       0.0         NNW           22.0         SE
# 145457      5.4     26.9       0.0           N           37.0         SE
# 145458      7.8     27.0       0.0          SE           28.0        SSE
#
#        WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# ...

# %%
data.isna().sum()
# Out:
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %%
sns.scatterplot(x='Humidity9am',y='MaxTemp',hue='RainTomorrow',palette='inferno',data=data);

# %%
sns.scatterplot(x='MinTemp',y='Rainfall',hue='RainTomorrow',palette='inferno',data=data);

# %%
sns.scatterplot(x='MaxTemp',y='WindGustSpeed',hue='RainTomorrow',palette='inferno',data=data);

# %%
sns.scatterplot(x='MaxTemp', y='MinTemp', hue='RainTomorrow', palette='inferno',data=data);

# %%
data_corr=data.corr()
data_corr
# Out:
#                 MinTemp   MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  \
# MinTemp        1.000000  0.728942  0.103807       0.159176      0.150577
# MaxTemp        0.728942  1.000000 -0.076825       0.056742     -0.006114
# Rainfall       0.103807 -0.076825  1.000000       0.130388      0.085376
# WindGustSpeed  0.159176  0.056742  0.130388       1.000000      0.589735
# WindSpeed9am   0.150577 -0.006114  0.085376       0.589735      1.000000
# WindSpeed3pm   0.146078  0.013976  0.060288       0.679223      0.499372
# Humidity9am   -0.218312 -0.517188  0.238756      -0.183729     -0.221500
# Humidity3pm    0.026733 -0.497679  0.259652      -0.020903     -0.017875
# Pressure9am   -0.433645 -0.312597 -0.167595      -0.445046     -0.201550
# Pressure3pm   -0.448298 -0.411360 -0.126520      -0.399751     -0.150433
# Temp9am        0.898785  0.884925  0.007418       0.124733      0.089493
# Temp3pm        0.704477  0.984357 -0.080376       0.018325     -0.019280
#
# ...

# %%
sns.heatmap(data_corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['WindGustDir']=le.fit_transform(data['WindGustDir'])
data['WindDir9am']=le.fit_transform(data['WindDir9am'])
data['WindDir3pm']=le.fit_transform(data['WindDir3pm'])
data['RainToday']=le.fit_transform(data['RainToday'])
data['RainTomorrow']=le.fit_transform(data['RainTomorrow']);
# Out:
# C:\Users\Theophilus Bassaw\AppData\Local\Temp\ipykernel_1468\1829674536.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['WindGustDir']=le.fit_transform(data['WindGustDir'])
# C:\Users\Theophilus Bassaw\AppData\Local\Temp\ipykernel_1468\1829674536.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['WindDir9am']=le.fit_transform(data['WindDir9am'])
# C:\Users\Theophilus Bassaw\AppData\Local\Temp\ipykernel_1468\1829674536.py:5: SettingWithCopyWarning:
# ...

# %%
x = data.drop(['RainTomorrow'],axis=1)
y = data['RainTomorrow']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.metrics import classification_report, confusion_matrix , accuracy_score

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train,y_train)
predictions=lr.predict(x_test)
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
print(accuracy_score(y_test,predictions))
# Out:
# [[16647   917]
#  [ 2578  2443]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.95      0.90     17564
#            1       0.73      0.49      0.58      5021
#
#     accuracy                           0.85     22585
#    macro avg       0.80      0.72      0.74     22585
# weighted avg       0.84      0.85      0.83     22585
#
# 0.8452512729687846
# C:\Users\Theophilus Bassaw\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
predictions
# Out:
# array([0, 0, 0, ..., 1, 1, 0])

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
predictions1 = lr.predict(x_test)
print(confusion_matrix,(y_test,predictions1))
print(classification_report,(y_test,predictions1))
print(accuracy_score,(y_test,predictions1))
# Out:
# <function confusion_matrix at 0x000002CD0D4E91F0> (75420     0
# 42264     0
# 113347    0
# 38376     0
# 93191     1
#          ..
# 93656     0
# 4957      0
# 93274     0
# 19049     0
# 89783     0
# Name: RainTomorrow, Length: 22585, dtype: int32, array([0.17219834, 0.09803582, 0.23062995, ..., 0.45467208, 0.50884433,
#        0.13549901]))
# <function classification_report at 0x000002CD0D4E9A60> (75420     0
# 42264     0
# 113347    0
# 38376     0
# 93191     1
#          ..
# 93656     0
# 4957      0
# 93274     0
# 19049     0
# 89783     0
# Name: RainTomorrow, Length: 22585, dtype: int32, array([0.17219834, 0.09803582, 0.23062995, ..., 0.45467208, 0.50884433,
#        0.13549901]))
# <function accuracy_score at 0x000002CD0D4E9160> (75420     0
# 42264     0
# 113347    0
# 38376     0
# 93191     1
#          ..
# 93656     0
# 4957      0
# 93274     0
# 19049     0
# 89783     0
# ...

# %%
x_test
# Out:
#         MinTemp  MaxTemp  Rainfall  WindGustDir  WindGustSpeed  WindDir9am  \
# 75420      13.2     23.1       0.0            2           30.0          13
# 42264      11.5     22.3       0.6           14           50.0          14
# 113347      9.7     23.5       0.0           14           43.0          15
# 38376       1.8     18.7       0.0            0           22.0           0
# 93191      22.3     28.7       0.0            4           41.0           1
# ...         ...      ...       ...          ...            ...         ...
# 93656      25.2     32.3       0.0            4           41.0           4
# 4957        3.5     14.7       0.0           12           50.0          13
# 93274      16.4     21.8       0.0            8           52.0           8
# 19049      13.1     18.2       4.0           10           41.0           8
# 89783      21.9     32.2       0.4            9           41.0           8
#
# ...
