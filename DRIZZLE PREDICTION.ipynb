# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import missingno as msno
#pd.set_option('display.max_rows')
plt.style.use('dark_background')

# %%
data = pd.read_csv('file.csv')
data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
data.head(10)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
# 5  1/1/2012 5:00    -1.4              -3.3         87                9
# 6  1/1/2012 6:00    -1.5              -3.1         89                7
# 7  1/1/2012 7:00    -1.4              -3.6         85                7
# 8  1/1/2012 8:00    -1.4              -3.6         85                9
# 9  1/1/2012 9:00    -1.3              -3.1         88               15
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# ...

# %%
data.drop('Date/Time',axis=1,inplace=True)

# %%
data
# Out:
#       Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  Visibility_km  \
# 0       -1.8              -3.9         86                4            8.0
# 1       -1.8              -3.7         87                4            8.0
# 2       -1.8              -3.4         89                7            4.0
# 3       -1.5              -3.2         88                6            4.0
# 4       -1.5              -3.3         88                7            4.8
# ...      ...               ...        ...              ...            ...
# 8779     0.1              -2.7         81               30            9.7
# 8780     0.2              -2.4         83               24            9.7
# 8781    -0.5              -1.5         93               28            4.8
# 8782    -0.2              -1.8         89               28            9.7
# 8783     0.0              -2.1         86               30           11.3
#
#       Press_kPa               Weather
# 0        101.24                   Fog
# ...

# %%
msno.bar(data)
# Out:
# <AxesSubplot:>

# %%
data=data.join(pd.get_dummies(data.Weather))
data
# Out:
#       Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  Visibility_km  \
# 0       -1.8              -3.9         86                4            8.0
# 1       -1.8              -3.7         87                4            8.0
# 2       -1.8              -3.4         89                7            4.0
# 3       -1.5              -3.2         88                6            4.0
# 4       -1.5              -3.3         88                7            4.8
# ...      ...               ...        ...              ...            ...
# 8779     0.1              -2.7         81               30            9.7
# 8780     0.2              -2.4         83               24            9.7
# 8781    -0.5              -1.5         93               28            4.8
# 8782    -0.2              -1.8         89               28            9.7
# 8783     0.0              -2.1         86               30           11.3
#
#       Press_kPa               Weather  Clear  Cloudy  Drizzle  ...  Snow,Fog  \
# ...

# %%
data=data[['Temp_C', 'Dew Point Temp_C', 'Rel Hum_%', 'Wind Speed_km/h',
       'Visibility_km', 'Press_kPa', 'Drizzle']].copy()

# %%
data
# Out:
#       Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  Visibility_km  \
# 0       -1.8              -3.9         86                4            8.0
# 1       -1.8              -3.7         87                4            8.0
# 2       -1.8              -3.4         89                7            4.0
# 3       -1.5              -3.2         88                6            4.0
# 4       -1.5              -3.3         88                7            4.8
# ...      ...               ...        ...              ...            ...
# 8779     0.1              -2.7         81               30            9.7
# 8780     0.2              -2.4         83               24            9.7
# 8781    -0.5              -1.5         93               28            4.8
# 8782    -0.2              -1.8         89               28            9.7
# 8783     0.0              -2.1         86               30           11.3
#
#       Press_kPa  Drizzle
# 0        101.24        0
# 1        101.24        0
# ...

# %%
x = data.drop(columns='Drizzle')

# %%
y = data.Drizzle

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=0)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_train
# Out:
#       Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  Visibility_km  \
# 8689    -4.4              -6.6         85               15            6.4
# 4445    20.3              17.1         82               15           12.9
# 5670    16.6              12.9         79               11           48.3
# 2851     6.1             -11.4         27               19           48.3
# 7274    14.1              10.3         78               37           25.0
# ...      ...               ...        ...              ...            ...
# 4373    20.2              12.3         60                0           24.1
# 7891    -0.9              -5.0         74               22           19.3
# 4859    24.7              13.7         50                9           48.3
# 3264    14.6              12.6         88                4           25.0
# 2732     5.7               3.6         86               41           25.0
#
#       Press_kPa
# 8689     100.83
# 4445     100.25
# 5670     101.76
# ...

# %%
y_train.values.reshape(-1,1)
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=uint8)

# %%
y_pre_train=lr.predict(x_train)

# %%
lr.score(x_train,y_train)
# Out:
# 0.009481872142016456

# %%
plt.scatter(y_train,y_pre_train)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
ypred_t=model.predict(x_train)

# %%
model.score(x_train,y_train)
# Out:
# 0.9954456733897202

# %%
model.fit(x_test,y_test)
# Out:
# LogisticRegression()

# %%
ypred_te=model.predict(x_test)

# %%
model.score(x_test,y_test)
# Out:
# 0.9950682852807283

# %%
from sklearn.metrics import classification_report, confusion_matrix , accuracy_score

# %%
print(confusion_matrix(y_test,ypred_te))
print(classification_report(y_test,ypred_te))
print(accuracy_score(y_test,ypred_te))
# Out:
# [[2623    0]
#  [  13    0]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2623
#            1       0.00      0.00      0.00        13
#
#     accuracy                           1.00      2636
#    macro avg       0.50      0.50      0.50      2636
# weighted avg       0.99      1.00      0.99      2636
#
# 0.9950682852807283
# C:\Users\Theophilus Bassaw\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Theophilus Bassaw\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
#pd.DataFrame(ypred_t)
