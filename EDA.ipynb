# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
plt.style.use('ggplot')
#pd.set_option('Maximum_columns',200)

# %%
df = pd.read_csv('Ghana_Covid19_DailyActive.csv')
df
# Out:
#      confirmed  recovered  death        date  cumulative_confirmed   \
# 0            2          0      0  03/12/2020                      2
# 1            2          0      0  03/13/2020                      4
# 2            2          0      0  03/14/2020                      6
# 3            1          0      0  03/17/2020                      7
# 4            2          0      0  03/18/2020                      9
# ..         ...        ...    ...         ...                    ...
# 228         49         78      0  11/23/2020                  51274
# 229        105         93      0  11/24/2020                  51379
# 230         97         60      0  11/25/2020                  51476
# 231         93         92      0  11/26/2020                  51569
# 232         98         97      0  11/27/2020                  51667
#
#      cumulative_recovered  cumulative_death  active_cases
# 0                       0                 0             2
# ...

# %%
df.head(20)
# Out:
#     confirmed  recovered  death        date  cumulative_confirmed   \
# 0           2          0      0  03/12/2020                      2
# 1           2          0      0  03/13/2020                      4
# 2           2          0      0  03/14/2020                      6
# 3           1          0      0  03/17/2020                      7
# 4           2          0      0  03/18/2020                      9
# 5           2          0      0  03/19/2020                     11
# 6           5          0      0  03/20/2020                     16
# 7           3          2      1  03/21/2020                     19
# 8           3          0      1  03/22/2020                     22
# 9           3          0      0  03/23/2020                     25
# 10         26          0      0  03/24/2020                     51
# 11         15          0      0  03/25/2020                     66
# 12         64          0      1  03/26/2020                    130
# ...

# %%
df.columns
# Out:
# Index(['confirmed', 'recovered', 'death', 'date', 'cumulative_confirmed ',
#        'cumulative_recovered', 'cumulative_death', 'active_cases'],
#       dtype='object')

# %%
df.dtypes
# Out:
# confirmed                 int64
# recovered                 int64
# death                     int64
# date                     object
# cumulative_confirmed      int64
# cumulative_recovered      int64
# cumulative_death          int64
# active_cases              int64
# dtype: object

# %%
df.date=pd.to_datetime(df.date)
df
# Out:
#      confirmed  recovered  death       date  cumulative_confirmed   \
# 0            2          0      0 2020-03-12                      2
# 1            2          0      0 2020-03-13                      4
# 2            2          0      0 2020-03-14                      6
# 3            1          0      0 2020-03-17                      7
# 4            2          0      0 2020-03-18                      9
# ..         ...        ...    ...        ...                    ...
# 228         49         78      0 2020-11-23                  51274
# 229        105         93      0 2020-11-24                  51379
# 230         97         60      0 2020-11-25                  51476
# 231         93         92      0 2020-11-26                  51569
# 232         98         97      0 2020-11-27                  51667
#
#      cumulative_recovered  cumulative_death  active_cases
# 0                       0                 0             2
# ...

# %%
df.describe()
# Out:
#          confirmed    recovered       death  cumulative_confirmed   \
# count   233.000000   233.000000  233.000000             233.000000
# mean    221.746781   216.939914    1.386266           28642.167382
# std     241.394370   441.662539    2.569077           19231.469481
# min       1.000000     0.000000    0.000000               2.000000
# 25%      59.000000    32.000000    0.000000            8070.000000
# 50%     131.000000    97.000000    0.000000           35501.000000
# 75%     295.000000   221.000000    2.000000           46626.000000
# max    1513.000000  5526.000000   15.000000           51667.000000
#
#        cumulative_recovered  cumulative_death  active_cases
# count            233.000000        233.000000    233.000000
# mean           26223.437768        174.386266   2244.343348
# std            20028.783253        124.097661   2066.144590
# min                0.000000          0.000000      2.000000
# 25%             2947.000000         36.000000    524.000000
# ...

# %%
df.isna().sum()
# Out:
# confirmed                0
# recovered                0
# death                    0
# date                     0
# cumulative_confirmed     0
# cumulative_recovered     0
# cumulative_death         0
# active_cases             0
# dtype: int64

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [confirmed, recovered, death, date, cumulative_confirmed , cumulative_recovered, cumulative_death, active_cases]
# Index: []

# %%
df.loc[df.duplicated(subset=['confirmed'])]
# Out:
#      confirmed  recovered  death        date  cumulative_confirmed   \
# 1            2          0      0  03/13/2020                      4
# 2            2          0      0  03/14/2020                      6
# 4            2          0      0  03/18/2020                      9
# 5            2          0      0  03/19/2020                     11
# 8            3          0      1  03/22/2020                     22
# 9            3          0      0  03/23/2020                     25
# 13           5          0      1  03/27/2020                    135
# 18           9          0      0  04/02/2020                    204
# 19           1          0      0  04/03/2020                    205
# 20           9          0      0  04/04/2020                    214
# 22          26          0      0  04/07/2020                    313
# 27           5          0      0  04/15/2020                    641
# 60         251        146      0  06/01/2020                   8548
# ...

# %%
df.active_cases.value_counts()
# Out:
# 382     2
# 499     2
# 16      2
# 554     2
# 3716    2
#        ..
# 3840    1
# 3947    1
# 3976    1
# 4071    1
# 797     1
# Name: active_cases, Length: 227, dtype: int64

# %%
df.date.value_counts() \
   .head(10) \
   .plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
ax=df.active_cases.plot(kind='bar',title='ACTIVE COVID CASES')
ax.set_xlabel('')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ax=sns.histplot('active_cases','date',data = df)
ax.set_xlabel('DATE')
ax.set_ylabel('ACTIVE CASES')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [90], in <cell line: 1>()
# ----> 1 ax=sns.histplot('active_cases','date',data = df)
#       2 ax.set_xlabel('DATE')
#       3 ax.set_ylabel('ACTIVE CASES')
#
# TypeError: histplot() got multiple values for argument 'data'

# %%
df.cumulative_death.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.scatterplot(x='active_cases',y='recovered',hue='death',data = df)
# Out:
# <AxesSubplot:xlabel='active_cases', ylabel='recovered'>

# %%
sns.pairplot(df,vars=['active_cases','recovered','confirmed','death'],hue='cumulative_recovered',palette='CMRmap')

# %%
df_corr=df[['confirmed', 'recovered', 'death', 'date', 'cumulative_confirmed ',
       'cumulative_recovered', 'cumulative_death', 'active_cases']].corr()

# %%
sns.heatmap(df_corr)
# Out:
# <AxesSubplot:>

# %%
df=df[['confirmed', 'recovered', 'death'
    #'date'
    ,
    'cumulative_confirmed ',
       'cumulative_recovered', 'cumulative_death', 'active_cases']]

# %%
sns.heatmap(df)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df)
# Out:
# <AxesSubplot:>
